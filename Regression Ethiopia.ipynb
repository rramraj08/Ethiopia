# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'alldatasets.xlsx',sheet_name='Ethiopia')

# %%
df.head()
# Out:
#     childid   country  height  stunting_2cat  EDUYRS2   z_score  timeschool  \
# 0  ET011003  Ethiopia   157.0            0.0     16.5  1.379536        15.0
# 1  ET011004  Ethiopia   174.0            NaN     10.0 -0.092591        30.0
# 2  ET011009  Ethiopia   155.0            0.0     12.5  1.785974        30.0
# 3  ET011010  Ethiopia   153.5            0.0     12.0  1.803539        30.0
# 4  ET011014  Ethiopia   169.0            0.0     10.0  0.893750        45.0
#
#    agegapr1  momeduyrsr1  chsexr1  agemonr1  hhsizer1  wi_newr1  job_cat  \
# 0       9.0         12.0        0        99         7  0.524603        5
# 1      10.0          6.0        1        90         8  0.473611        3
# 2      14.0          8.0        0        90        13  0.562821        5
# 3       NaN          NaN        0        91         3  0.320370        5
# 4       3.0          0.0        1        99         6  0.409259        3
#
#    pvt_sector     earn     earn_usd
# 0           1   2000.0    92.032104
# 1           1  32000.0  1472.513672
# 2           1   7000.0   322.112366
# 3           1   3600.0   165.657791
# 4           1  43200.0  1987.893433

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603 entries, 0 to 602
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   childid        603 non-null    object
#  1   country        603 non-null    object
#  2   height         603 non-null    float64
#  3   stunting_2cat  580 non-null    float64
#  4   EDUYRS2        603 non-null    float64
#  5   z_score        577 non-null    float64
#  6   timeschool     559 non-null    float64
#  7   agegapr1       451 non-null    float64
#  8   momeduyrsr1    554 non-null    float64
#  9   chsexr1        603 non-null    int64
#  10  agemonr1       603 non-null    int64
#  11  hhsizer1       603 non-null    int64
#  12  wi_newr1       602 non-null    float64
#  13  job_cat        603 non-null    int64
#  14  pvt_sector     603 non-null    int64
#  15  earn           603 non-null    float64
#  16  earn_usd       603 non-null    float64
# dtypes: float64(10), int64(5), object(2)
# memory usage: 80.2+ KB

# %%
import statsmodels.api as sm

# %% [markdown]
# # cognition

# %%
#cognition

X = df["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df["z_score"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                z_score   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     17.73
# Date:                Mon, 10 May 2021   Prob (F-statistic):           2.97e-05
# Time:                        13:23:18   Log-Likelihood:                -764.17
# No. Observations:                 555   AIC:                             1532.
# Df Residuals:                     553   BIC:                             1541.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0489      0.050     -0.986      0.324      -0.146       0.049
# stunting_2cat    -0.3668      0.087     -4.211      0.000      -0.538      -0.196
# ==============================================================================
# Omnibus:                        8.363   Durbin-Watson:                   1.469
# Prob(Omnibus):                  0.015   Jarque-Bera (JB):                5.568
# Skew:                           0.087   Prob(JB):                       0.0618
# Kurtosis:                       2.541   Cond. No.                         2.41
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Height

# %%
#Height

X = df["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df["height"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 height   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.056
# Method:                 Least Squares   F-statistic:                     35.26
# Date:                Mon, 10 May 2021   Prob (F-statistic):           4.98e-09
# Time:                        13:23:18   Log-Likelihood:                -2039.8
# No. Observations:                 580   AIC:                             4084.
# Df Residuals:                     578   BIC:                             4092.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           167.5312      0.417    402.109      0.000     166.713     168.350
# stunting_2cat    -4.2557      0.717     -5.938      0.000      -5.663      -2.848
# ==============================================================================
# Omnibus:                       11.451   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):                6.960
# Skew:                          -0.085   Prob(JB):                       0.0308
# Kurtosis:                       2.491   Cond. No.                         2.41
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # education

# %%
#education

X = df["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df["EDUYRS2"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                EDUYRS2   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     22.74
# Date:                Mon, 10 May 2021   Prob (F-statistic):           2.35e-06
# Time:                        13:23:18   Log-Likelihood:                -1448.0
# No. Observations:                 580   AIC:                             2900.
# Df Residuals:                     578   BIC:                             2909.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             8.8086      0.150     58.653      0.000       8.514       9.104
# stunting_2cat    -1.2321      0.258     -4.769      0.000      -1.739      -0.725
# ==============================================================================
# Omnibus:                       20.787   Durbin-Watson:                   1.547
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.460
# Skew:                          -0.477   Prob(JB):                     1.33e-05
# Kurtosis:                       2.868   Cond. No.                         2.41
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # cognition covariates

# %%
df.columns
# Out:
# Index(['childid', 'country', 'height', 'stunting_2cat', 'EDUYRS2', 'z_score',
#        'timeschool', 'agegapr1', 'momeduyrsr1', 'chsexr1', 'agemonr1',
#        'hhsizer1', 'wi_newr1', 'job_cat', 'pvt_sector', 'earn', 'earn_usd'],
#       dtype='object')

# %%
X = df[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df["z_score"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                z_score   R-squared:                       0.245
# Model:                            OLS   Adj. R-squared:                  0.231
# Method:                 Least Squares   F-statistic:                     18.60
# Date:                Mon, 10 May 2021   Prob (F-statistic):           1.75e-21
# Time:                        13:23:18   Log-Likelihood:                -504.05
# No. Observations:                 410   AIC:                             1024.
# Df Residuals:                     402   BIC:                             1056.
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.7587      1.119      0.678      0.498      -1.441       2.959
# stunting_2cat    -0.2416      0.090     -2.674      0.008      -0.419      -0.064
# agemonr1         -0.0150      0.012     -1.279      0.202      -0.038       0.008
# chsexr1           0.2297      0.085      2.693      0.007       0.062       0.397
# agegapr1          0.0082      0.007      1.265      0.207      -0.005       0.021
# momeduyrsr1       0.0147      0.016      0.895      0.371      -0.018       0.047
# hhsizer1         -0.0220      0.022     -0.978      0.329      -0.066       0.022
# wi_newr1          2.3001      0.275      8.349      0.000       1.759       2.842
# ==============================================================================
# Omnibus:                        3.830   Durbin-Watson:                   1.817
# Prob(Omnibus):                  0.147   Jarque-Bera (JB):                2.796
# Skew:                          -0.016   Prob(JB):                        0.247
# Kurtosis:                       2.597   Cond. No.                     2.59e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.59e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # Height covariates

# %%
X = df[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df["height"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 height   R-squared:                       0.550
# Model:                            OLS   Adj. R-squared:                  0.542
# Method:                 Least Squares   F-statistic:                     72.94
# Date:                Mon, 10 May 2021   Prob (F-statistic):           1.56e-68
# Time:                        13:23:18   Log-Likelihood:                -1346.0
# No. Observations:                 426   AIC:                             2708.
# Df Residuals:                     418   BIC:                             2740.
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           154.2096      7.539     20.455      0.000     139.390     169.029
# stunting_2cat    -4.7986      0.605     -7.930      0.000      -5.988      -3.609
# agemonr1          0.0634      0.079      0.800      0.424      -0.092       0.219
# chsexr1          11.8320      0.577     20.523      0.000      10.699      12.965
# agegapr1         -0.0283      0.044     -0.638      0.524      -0.115       0.059
# momeduyrsr1       0.0475      0.111      0.426      0.670      -0.172       0.267
# hhsizer1          0.1329      0.151      0.879      0.380      -0.164       0.430
# wi_newr1          0.7472      1.874      0.399      0.690      -2.937       4.432
# ==============================================================================
# Omnibus:                        2.044   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.360   Jarque-Bera (JB):                1.994
# Skew:                           0.036   Prob(JB):                        0.369
# Kurtosis:                       3.327   Cond. No.                     2.59e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.59e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # education covariates

# %%
X = df[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df["EDUYRS2"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                EDUYRS2   R-squared:                       0.262
# Model:                            OLS   Adj. R-squared:                  0.250
# Method:                 Least Squares   F-statistic:                     21.25
# Date:                Mon, 10 May 2021   Prob (F-statistic):           1.63e-24
# Time:                        13:23:18   Log-Likelihood:                -1003.4
# No. Observations:                 426   AIC:                             2023.
# Df Residuals:                     418   BIC:                             2055.
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            12.1557      3.374      3.603      0.000       5.525      18.787
# stunting_2cat    -0.9539      0.271     -3.523      0.000      -1.486      -0.422
# agemonr1         -0.0431      0.035     -1.214      0.225      -0.113       0.027
# chsexr1          -0.8210      0.258     -3.182      0.002      -1.328      -0.314
# agegapr1          0.0241      0.020      1.218      0.224      -0.015       0.063
# momeduyrsr1       0.1168      0.050      2.342      0.020       0.019       0.215
# hhsizer1         -0.0799      0.068     -1.181      0.238      -0.213       0.053
# wi_newr1          6.8383      0.839      8.153      0.000       5.190       8.487
# ==============================================================================
# Omnibus:                        5.844   Durbin-Watson:                   1.800
# Prob(Omnibus):                  0.054   Jarque-Bera (JB):                5.978
# Skew:                          -0.279   Prob(JB):                       0.0503
# Kurtosis:                       2.840   Cond. No.                     2.59e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.59e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
